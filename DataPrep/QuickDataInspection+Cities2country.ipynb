# %%
import numpy as np
import pandas as pd

# %%
cities_population = pd.read_csv('Data\CITIES_POPULATION.csv',sep="|")
cities_territory = pd.read_csv('Data\CITIES_TERRITORY.csv',sep="|")

country_codes = pd.read_excel('Extra variables\code_country.xls')
country_inlandwater = pd.read_csv('Extra variables\OECD_Country_InlandWater.csv')
country_roaddensity = pd.read_csv('Extra variables\Km of road per 100 sq. km of land area.csv')

# %%
#OECD set of population contains the best reference in terms of number of unique cities
cities_set = set(cities_population['METRO_ID'])
cities_set

country_dict = country_codes[['CODE','Country']].to_dict('records')
country_dict
# Out:
# [{'CODE': 'ABW', 'Country': 'Aruba'},
#  {'CODE': 'AFG', 'Country': 'Afghanistan'},
#  {'CODE': 'AFRI', 'Country': 'Africa'},
#  {'CODE': 'AGO', 'Country': 'Angola'},
#  {'CODE': 'AIA', 'Country': 'Anguilla'},
#  {'CODE': 'ALB', 'Country': 'Albania'},
#  {'CODE': 'AND', 'Country': 'Andorra'},
#  {'CODE': 'ANT', 'Country': 'Netherlands Antilles'},
#  {'CODE': 'ARE', 'Country': 'United Arab Emirates'},
#  {'CODE': 'ARG', 'Country': 'Argentina'},
#  {'CODE': 'ASIA', 'Country': 'Asia'},
#  {'CODE': 'ASM', 'Country': 'American Samoa'},
#  {'CODE': 'ATG', 'Country': 'Antigua and Barbuda'},
#  {'CODE': 'AUS', 'Country': 'Australia'},
#  {'CODE': 'AUT', 'Country': 'Austria'},
#  {'CODE': 'BDI', 'Country': 'Burundi'},
#  {'CODE': 'BEL', 'Country': 'Belgium'},
#  {'CODE': 'BEN', 'Country': 'Benin'},
#  {'CODE': 'BFA', 'Country': 'Burkina Faso'},
#  {'CODE': 'BGD', 'Country': 'Bangladesh'},
#  {'CODE': 'BGR', 'Country': 'Bulgaria'},
#  {'CODE': 'BHR', 'Country': 'Bahrain'},
#  {'CODE': 'BHS', 'Country': 'Bahamas'},
#  {'CODE': 'BLZ', 'Country': 'Belize'},
#  {'CODE': 'BMU', 'Country': 'Bermuda'},
#  {'CODE': 'BOL', 'Country': 'Bolivia'},
#  {'CODE': 'BRA', 'Country': 'Brazil'},
#  {'CODE': 'BRB', 'Country': 'Barbados'},
#  {'CODE': 'BRN', 'Country': 'Brunei Darussalam'},
#  {'CODE': 'BTN', 'Country': 'Bhutan'},
#  {'CODE': 'BWA', 'Country': 'Botswana'},
#  {'CODE': 'CAF', 'Country': 'Central African Republic'},
#  {'CODE': 'CAN', 'Country': 'Canada'},
#  {'CODE': 'CCK', 'Country': 'Cocos (Keeling) Islands'},
#  {'CODE': 'CHE', 'Country': 'Switzerland'},
#  {'CODE': 'CHL', 'Country': 'Chile'},
#  {'CODE': 'CHN', 'Country': 'China'},
#  {'CODE': 'CIV', 'Country': "Côte d'Ivoire"},
#  {'CODE': 'CMR', 'Country': 'Cameroon'},
#  {'CODE': 'COD', 'Country': 'Congo, Dem. Rep. Of'},
#  {'CODE': 'COG', 'Country': 'Congo'},
#  {'CODE': 'COK', 'Country': 'Cook Islands'},
#  {'CODE': 'COL', 'Country': 'Colombia'},
#  {'CODE': 'COM', 'Country': 'Comoros'},
#  {'CODE': 'CPV', 'Country': 'Cape Verde'},
#  {'CODE': 'CRI', 'Country': 'Costa Rica'},
#  {'CODE': 'CSFR', 'Country': 'Former Czechoslovakia'},
#  {'CODE': 'CSFR-CZE', 'Country': 'Czech Republic'},
#  {'CODE': 'CSFR-SVK', 'Country': 'Slovak Republic'},
#  {'CODE': 'CUB', 'Country': 'Cuba'},
#  {'CODE': 'CYM', 'Country': 'Cayman Islands'},
#  {'CODE': 'CYP', 'Country': 'Cyprus'},
#  {'CODE': 'DEU', 'Country': 'Germany'},
#  {'CODE': 'DJI', 'Country': 'Djibouti'},
#  {'CODE': 'DMA', 'Country': 'Dominica'},
#  {'CODE': 'DNK', 'Country': 'Denmark'},
#  {'CODE': 'DOM', 'Country': 'Dominican Republic'},
#  {'CODE': 'DZA', 'Country': 'Algeria'},
#  {'CODE': 'ECU', 'Country': 'Ecuador'},
#  {'CODE': 'EGY', 'Country': 'Egypt'},
#  {'CODE': 'ERI', 'Country': 'Eritrea'},
#  {'CODE': 'ESH', 'Country': 'Western Sahara'},
#  {'CODE': 'ESP', 'Country': 'Spain'},
#  {'CODE': 'ETH', 'Country': 'Ethiopia'},
#  {'CODE': 'EURO', 'Country': 'Europe'},
#  {'CODE': 'FIN', 'Country': 'Finland'},
#  {'CODE': 'FJI', 'Country': 'Fiji'},
#  {'CODE': 'FLK', 'Country': 'Falkland Islands'},
#  {'CODE': 'FRA', 'Country': 'France'},
#  {'CODE': 'FSM', 'Country': 'Micronesia, Federated states of'},
#  {'CODE': 'FYUG', 'Country': 'Former Yugoslavia'},
#  {'CODE': 'FYUG-BIH', 'Country': 'Bosnia-Herzegovina'},
#  {'CODE': 'FYUG-HRV', 'Country': 'Croatia'},
#  {'CODE': 'FYUG-MKD', 'Country': 'Macedonia'},
#  {'CODE': 'FYUG-SVN', 'Country': 'Slovenia'},
#  {'CODE': 'FYUG-YUG', 'Country': 'Serbia and Montenegro'},
#  {'CODE': 'GAB', 'Country': 'Gabon'},
#  {'CODE': 'GBR', 'Country': 'United Kingdom'},
#  {'CODE': 'GHA', 'Country': 'Ghana'},
#  {'CODE': 'GIB', 'Country': 'Gibraltar'},
#  {'CODE': 'GIN', 'Country': 'Guinea'},
#  {'CODE': 'GMB', 'Country': 'Gambia'},
#  {'CODE': 'GNB', 'Country': 'Guinea-Bissau'},
#  {'CODE': 'GNQ', 'Country': 'Equatorial Guinea'},
#  {'CODE': 'GRC', 'Country': 'Greece'},
#  {'CODE': 'GRD', 'Country': 'Grenada'},
#  {'CODE': 'GTM', 'Country': 'Guatemala'},
#  {'CODE': 'GUM', 'Country': 'Guam'},
#  {'CODE': 'GUY', 'Country': 'Guyana'},
#  {'CODE': 'HKG', 'Country': 'Hong Kong'},
#  {'CODE': 'HND', 'Country': 'Honduras'},
#  {'CODE': 'HTI', 'Country': 'Haiti'},
#  {'CODE': 'HUN', 'Country': 'Hungary'},
#  {'CODE': 'IDN', 'Country': 'Indonesia'},
#  {'CODE': 'IND', 'Country': 'India'},
#  {'CODE': 'IOT', 'Country': 'British Indian Ocean Territory'},
#  {'CODE': 'IRL', 'Country': 'Ireland'},
#  {'CODE': 'IRN', 'Country': 'Iran'},
#  {'CODE': 'IRQ', 'Country': 'Iraq'},
#  {'CODE': 'ISL', 'Country': 'Iceland'},
#  {'CODE': 'ISR', 'Country': 'Israel'},
#  {'CODE': 'ITA', 'Country': 'Italy'},
#  {'CODE': 'JAM', 'Country': 'Jamaica'},
#  {'CODE': 'JOR', 'Country': 'Jordan'},
#  {'CODE': 'JPN', 'Country': 'Japan'},
#  {'CODE': 'KEN', 'Country': 'Kenya'},
#  {'CODE': 'KHM', 'Country': 'Cambodia'},
#  {'CODE': 'KIR', 'Country': 'Kiribati'},
#  {'CODE': 'KNA', 'Country': 'Saint Kitts and Nevis'},
#  {'CODE': 'KOREA-NO', 'Country': 'North Korea'},
#  {'CODE': 'KOREA-NS', 'Country': 'South Korea'},
#  {'CODE': 'KOREA-SO', 'Country': 'North and South Korea'},
#  {'CODE': 'KWT', 'Country': 'Kuwait'},
#  {'CODE': 'LAO', 'Country': 'Laos'},
#  {'CODE': 'LBN', 'Country': 'Lebanon'},
#  {'CODE': 'LBR', 'Country': 'Liberia'},
#  {'CODE': 'LBY', 'Country': 'Libya'},
#  {'CODE': 'LCA', 'Country': 'Saint Lucia'},
#  {'CODE': 'LIE', 'Country': 'Liechtenstein'},
#  {'CODE': 'LKA', 'Country': 'Sri Lanka'},
#  {'CODE': 'LSO', 'Country': 'Lesotho'},
#  {'CODE': 'LUX', 'Country': 'Luxembourg'},
#  {'CODE': 'MAC', 'Country': 'Macau'},
#  {'CODE': 'MAR', 'Country': 'Morocco'},
#  {'CODE': 'MCO', 'Country': 'Monaco'},
#  {'CODE': 'MDG', 'Country': 'Madagascar'},
#  {'CODE': 'MDV', 'Country': 'Maldives'},
#  {'CODE': 'MEX', 'Country': 'Mexico'},
#  {'CODE': 'MHL', 'Country': 'Marshall Islands'},
#  {'CODE': 'MLI', 'Country': 'Mali'},
#  {'CODE': 'MLT', 'Country': 'Malta'},
#  {'CODE': 'MMR', 'Country': 'Myanmar'},
#  {'CODE': 'MNG', 'Country': 'Mongolia'},
#  {'CODE': 'MNP', 'Country': 'Northern Mariana Islands'},
#  {'CODE': 'MOZ', 'Country': 'Mozambique'},
#  {'CODE': 'MRT', 'Country': 'Mauritania'},
#  {'CODE': 'MSR', 'Country': 'Montserrat'},
#  {'CODE': 'MUS', 'Country': 'Mauritius'},
#  {'CODE': 'MWI', 'Country': 'Malawi'},
#  {'CODE': 'MYS', 'Country': 'Malaysia'},
#  {'CODE': 'NAM', 'Country': 'Namibia'},
#  {'CODE': 'NER', 'Country': 'Niger'},
#  {'CODE': 'NFK', 'Country': 'Norfolk Islands'},
#  {'CODE': 'NGA', 'Country': 'Nigeria'},
#  {'CODE': 'NIC', 'Country': 'Nicaragua'},
#  {'CODE': 'NIU', 'Country': 'Niue'},
#  {'CODE': 'NLD', 'Country': 'Netherlands'},
#  {'CODE': 'NOAM', 'Country': 'North America'},
#  {'CODE': 'NOR', 'Country': 'Norway'},
#  {'CODE': 'NPL', 'Country': 'Nepal'},
#  {'CODE': 'NRU', 'Country': 'Nauru'},
#  {'CODE': 'NZL', 'Country': 'New Zealand'},
#  {'CODE': 'OCEA', 'Country': 'Oceania'},
#  {'CODE': 'OMN', 'Country': 'Oman'},
#  {'CODE': 'OTH', 'Country': 'Other'},
#  {'CODE': 'PAK', 'Country': 'Pakistan'},
#  {'CODE': 'PAN', 'Country': 'Panama'},
#  {'CODE': 'PCN', 'Country': 'Pitcairn'},
#  {'CODE': 'PER', 'Country': 'Peru'},
#  {'CODE': 'PHL', 'Country': 'Philippines'},
#  {'CODE': 'PLW', 'Country': 'Pacific Islands (Palau)'},
#  {'CODE': 'PNG', 'Country': 'Papua New Guinea'},
#  {'CODE': 'POL', 'Country': 'Poland'},
#  {'CODE': 'PRI', 'Country': 'Puerto Rico'},
#  {'CODE': 'PRT', 'Country': 'Portugal'},
#  {'CODE': 'PRY', 'Country': 'Paraguay'},
#  {'CODE': 'PSE', 'Country': 'Occupied Palestinian Territory'},
#  {'CODE': 'QAT', 'Country': 'Qatar'},
#  {'CODE': 'ROU', 'Country': 'Romania'},
#  {'CODE': 'RWA', 'Country': 'Rwanda'},
#  {'CODE': 'SAU', 'Country': 'Saudi Arabia'},
#  {'CODE': 'SCAC', 'Country': 'South and Central America'},
#  {'CODE': 'SDN', 'Country': 'Sudan'},
#  {'CODE': 'SEN', 'Country': 'Senegal'},
#  {'CODE': 'SGP', 'Country': 'Singapore'},
#  {'CODE': 'SHN', 'Country': 'Saint Helena'},
#  {'CODE': 'SJM', 'Country': 'Svalbard and Jan Mayen Islands'},
#  {'CODE': 'SLB', 'Country': 'Solomon Islands'},
#  {'CODE': 'SLE', 'Country': 'Sierra Leone'},
#  {'CODE': 'SLV', 'Country': 'El Salvador'},
#  {'CODE': 'SMR', 'Country': 'San Marino'},
#  {'CODE': 'SOM', 'Country': 'Somalia'},
#  {'CODE': 'STP', 'Country': 'Sao Tome and Principe'},
#  {'CODE': 'SUR', 'Country': 'Suriname'},
#  {'CODE': 'SWE', 'Country': 'Sweden'},
#  {'CODE': 'SWZ', 'Country': 'Swaziland'},
#  {'CODE': 'SYC', 'Country': 'Seychelles'},
#  {'CODE': 'SYR', 'Country': 'Syria'},
#  {'CODE': 'TCA', 'Country': 'Turks and Caicos Islands'},
#  {'CODE': 'TCD', 'Country': 'Chad'},
#  {'CODE': 'TGO', 'Country': 'Togo'},
#  {'CODE': 'THA', 'Country': 'Thailand'},
#  {'CODE': 'TKL', 'Country': 'Tokelau'},
#  {'CODE': 'TLS', 'Country': 'Timor-Leste'},
#  {'CODE': 'TMP', 'Country': 'East Timor'},
#  {'CODE': 'TON', 'Country': 'Tonga'},
#  {'CODE': 'TTO', 'Country': 'Trinidad and Tobago'},
#  {'CODE': 'TUN', 'Country': 'Tunisia'},
#  {'CODE': 'TUR', 'Country': 'Turkey'},
#  {'CODE': 'TUV', 'Country': 'Tuvalu'},
#  {'CODE': 'TWN', 'Country': 'Chinese Taipei'},
#  {'CODE': 'TZA', 'Country': 'United Republic of Tanzania'},
#  {'CODE': 'UGA', 'Country': 'Unknown'},
#  {'CODE': 'UNK', 'Country': 'Unknown'},
#  {'CODE': 'URY', 'Country': 'Uruguay'},
#  {'CODE': 'USA', 'Country': 'United States'},
#  {'CODE': 'USSR', 'Country': 'Former USSR'},
#  {'CODE': 'USSR-ARM', 'Country': 'Armenia'},
#  {'CODE': 'USSR-AZE', 'Country': 'Azerbaidjan'},
#  {'CODE': 'USSR-BLR', 'Country': 'Belarus'},
#  {'CODE': 'USSR-EST', 'Country': 'Estonia'},
#  {'CODE': 'USSR-GEO', 'Country': 'Georgia'},
#  {'CODE': 'USSR-KAZ', 'Country': 'Kazakhstan'},
#  {'CODE': 'USSR-KGZ', 'Country': 'Kirghizistan'},
#  {'CODE': 'USSR-LTU', 'Country': 'Lithuania'},
#  {'CODE': 'USSR-LVA', 'Country': 'Latvia'},
#  {'CODE': 'USSR-MDA', 'Country': 'Moldova'},
#  {'CODE': 'USSR-RUS', 'Country': 'Russia'},
#  {'CODE': 'USSR-TJK', 'Country': 'Tadjikistan'},
#  {'CODE': 'USSR-TKM', 'Country': 'Turkménistan'},
#  {'CODE': 'USSR-UKR', 'Country': 'Ukraine'},
#  {'CODE': 'USSR-UZB', 'Country': 'Uzbekistan'},
#  {'CODE': 'VAT', 'Country': 'Holy See'},
#  {'CODE': 'VCT', 'Country': 'Saint Vincent and the Grenadines'},
#  {'CODE': 'VEN', 'Country': 'Venezuela'},
#  {'CODE': 'VGB', 'Country': 'British Virgin Islands'},
#  {'CODE': 'VIR', 'Country': 'United States Virgin Islands'},
#  {'CODE': 'VNM', 'Country': 'Vietnam'},
#  {'CODE': 'VUT', 'Country': 'Vanuatu'},
#  {'CODE': 'WSM', 'Country': 'Samoa'},
#  {'CODE': 'YEM', 'Country': 'Yemen'},
#  {'CODE': 'ZAF', 'Country': 'South Africa'},
#  {'CODE': 'ZMB', 'Country': 'Zambia'},
#  {'CODE': 'ZWE', 'Country': 'Zimbabwe'}]

# %%
#function that selects first few letters of a string

def first_letters(string):
    output = ''
    for char in range(len(string)):
        if ord(str(string[char])) >= 65:
            output += str(string[char])
    return output

# %%
#Built dictionairy which relates every city to the country it belongs to

dict_country_city = dict.fromkeys(cities_set,0)
dict_country_city

for city in dict_country_city.keys():
    for i in range(len(country_dict)):
        if len(first_letters(city)) > 2:
            if city[:3] == country_dict[i]['CODE'][:3]:
                dict_country_city[city] = country_dict[i]['Country']
        else:
            if city[:2] == country_dict[i]['CODE'][:2]:
                dict_country_city[city] = country_dict[i]['Country']

#exception handling
for entry in dict_country_city.keys():
    if first_letters(entry) == 'UK':
        dict_country_city[entry] = 'United Kingdom'
    elif first_letters(entry) == 'CL':
        dict_country_city[entry] = 'Chile'
    elif first_letters(entry) == 'SI':
        dict_country_city[entry] = 'Slovakia'
    elif first_letters(entry) == 'LV':
        dict_country_city[entry] = 'Latvia'
    elif first_letters(entry) == 'SK':
        dict_country_city[entry] = 'Slovakia'
    elif first_letters(entry) == 'PT':
        dict_country_city[entry] = 'Portugal'
    elif first_letters(entry) == 'EE':
        dict_country_city[entry] = 'Estonia'
    elif first_letters(entry) == 'IE':
        dict_country_city[entry] = 'Ireland'
    elif first_letters(entry) == 'EL':
        dict_country_city[entry] = 'Greece'
    elif first_letters(entry) == 'DK':
        dict_country_city[entry] = 'Denmark'
    elif first_letters(entry) == 'CZ':
        dict_country_city[entry] = 'Czech Republic'
    elif first_letters(entry) == 'PL':
        dict_country_city[entry] = 'Poland'
    elif first_letters(entry) == 'AT':
        dict_country_city[entry] = 'Austria'
    elif first_letters(entry) == 'KOR':
        dict_country_city[entry] = 'South Korea'
    elif first_letters(entry) == 'LT':
        dict_country_city[entry] = 'South Korea'

        
dict_country_city
# Out:
# {'USA08': 'United States',
#  'AT004': 'Austria',
#  'USA66': 'United States',
#  'JPN42': 'Japan',
#  'ES501': 'Spain',
#  'JPN25': 'Japan',
#  'CL011': 'Chile',
#  'KOR11': 'South Korea',
#  'FR009': 'France',
#  'PL514': 'Poland',
#  'USA68': 'United States',
#  'CAN10': 'Canada',
#  'NL511': 'Netherlands',
#  'KOR20': 'South Korea',
#  'ES004': 'Spain',
#  'JPN18': 'Japan',
#  'KOR05': 'South Korea',
#  'DE045': 'Germany',
#  'DE021': 'Germany',
#  'PL011': 'Poland',
#  'DE042': 'Germany',
#  'USA133': 'United States',
#  'USA108': 'United States',
#  'CAN11': 'Canada',
#  'KOR19': 'South Korea',
#  'MEX57': 'Mexico',
#  'HU005': 'Hungary',
#  'MEX23': 'Mexico',
#  'DE031': 'Germany',
#  'EE001': 'Estonia',
#  'CH004': 'China',
#  'FR215': 'France',
#  'USA14': 'United States',
#  'MEX30': 'Mexico',
#  'JPN52': 'Japan',
#  'UK513': 'United Kingdom',
#  'USA116': 'United States',
#  'DE517': 'Germany',
#  'LT001': 'South Korea',
#  'COL05': 'Colombia',
#  'CL010': 'Chile',
#  'LU001': 'Luxembourg',
#  'JPN41': 'Japan',
#  'DE052': 'Germany',
#  'DE540': 'Germany',
#  'DE025': 'Germany',
#  'ES505': 'Spain',
#  'FR013': 'France',
#  'UK026': 'United Kingdom',
#  'DE044': 'Germany',
#  'MEX25': 'Mexico',
#  'PL014': 'Poland',
#  'PL020': 'Poland',
#  'MEX09': 'Mexico',
#  'JPN10': 'Japan',
#  'FR020': 'France',
#  'CH005': 'China',
#  'USA04': 'United States',
#  'FR008': 'France',
#  'FI003': 'Finland',
#  'MEX44': 'Mexico',
#  'DE529': 'Germany',
#  'CZ004': 'Czech Republic',
#  'USA89': 'United States',
#  'JPN08': 'Japan',
#  'KOR04': 'South Korea',
#  'EL001': 'Greece',
#  'USA131': 'United States',
#  'DE012': 'Germany',
#  'USA91': 'United States',
#  'UK560': 'United Kingdom',
#  'BE004': 'Benin',
#  'JPN14': 'Japan',
#  'USA106': 'United States',
#  'FR014': 'France',
#  'DE544': 'Germany',
#  'PL005': 'Poland',
#  'FR007': 'France',
#  'LT002': 'South Korea',
#  'DE083': 'Germany',
#  'DE018': 'Germany',
#  'USA138': 'United States',
#  'DE004': 'Germany',
#  'CAN15': 'Canada',
#  'IT029': 'Italy',
#  'MEX53': 'Mexico',
#  'PL001': 'Poland',
#  'IT012': 'Italy',
#  'HU002': 'Hungary',
#  'USA40': 'United States',
#  'DE542': 'Germany',
#  'ES020': 'Spain',
#  'SE006': 'Senegal',
#  'USA44': 'United States',
#  'USA02': 'United States',
#  'USA103': 'United States',
#  'JPN21': 'Japan',
#  'COL19': 'Colombia',
#  'DE054': 'Germany',
#  'MEX61': 'Mexico',
#  'UK550': 'United Kingdom',
#  'IT016': 'Italy',
#  'USA114': 'United States',
#  'FR205': 'France',
#  'PL004': 'Poland',
#  'IT011': 'Italy',
#  'USA119': 'United States',
#  'FR214': 'France',
#  'UK006': 'United Kingdom',
#  'UK525': 'United Kingdom',
#  'IT501': 'Italy',
#  'PT005': 'Portugal',
#  'USA34': 'United States',
#  'USA100': 'United States',
#  'COL18': 'Colombia',
#  'USA20': 'United States',
#  'FR016': 'France',
#  'JPN09': 'Japan',
#  'USA124': 'United States',
#  'UK009': 'United Kingdom',
#  'USA118': 'United States',
#  'USA12': 'United States',
#  'COL21': 'Colombia',
#  'USA72': 'United States',
#  'ES021': 'Spain',
#  'MEX50': 'Mexico',
#  'USA113': 'United States',
#  'UK002': 'United Kingdom',
#  'FR037': 'France',
#  'USA132': 'United States',
#  'FR039': 'France',
#  'USA17': 'United States',
#  'DE028': 'Germany',
#  'COL04': 'Colombia',
#  'USA18': 'United States',
#  'AUS06': 'Australia',
#  'UK562': 'United Kingdom',
#  'USA45': 'United States',
#  'JPN27': 'Japan',
#  'CH003': 'China',
#  'USA49': 'United States',
#  'FR040': 'France',
#  'BE003': 'Benin',
#  'MEX35': 'Mexico',
#  'USA35': 'United States',
#  'ES002': 'Spain',
#  'USA51': 'United States',
#  'USA15': 'United States',
#  'DE036': 'Germany',
#  'UK012': 'United Kingdom',
#  'AUS03': 'Australia',
#  'DE520': 'Germany',
#  'LV001': 'Latvia',
#  'USA25': 'United States',
#  'USA60': 'United States',
#  'DE017': 'Germany',
#  'CL025': 'Chile',
#  'MEX63': 'Mexico',
#  'USA110': 'United States',
#  'UK546': 'United Kingdom',
#  'SE003': 'Senegal',
#  'JPN03': 'Japan',
#  'DE034': 'Germany',
#  'FI001': 'Finland',
#  'MEX13': 'Mexico',
#  'IT508': 'Italy',
#  'MEX41': 'Mexico',
#  'USA135': 'United States',
#  'JPN51': 'Japan',
#  'FR034': 'France',
#  'MEX36': 'Mexico',
#  'JPN20': 'Japan',
#  'UK553': 'United Kingdom',
#  'KOR17': 'South Korea',
#  'NL007': 'Netherlands',
#  'MEX06': 'Mexico',
#  'SK002': 'Slovakia',
#  'JPN07': 'Japan',
#  'KOR06': 'South Korea',
#  'DE040': 'Germany',
#  'IT009': 'Italy',
#  'JPN26': 'Japan',
#  'USA146': 'United States',
#  'USA96': 'United States',
#  'JPN49': 'Japan',
#  'CAN01': 'Canada',
#  'UK566': 'United Kingdom',
#  'KOR10': 'South Korea',
#  'MEX51': 'Mexico',
#  'JPN01': 'Japan',
#  'JPN29': 'Japan',
#  'AUS07': 'Australia',
#  'DE043': 'Germany',
#  'IT004': 'Italy',
#  'NL514': 'Netherlands',
#  'DE074': 'Germany',
#  'KOR12': 'South Korea',
#  'IT030': 'Italy',
#  'PT001': 'Portugal',
#  'USA144': 'United States',
#  'KOR13': 'South Korea',
#  'MEX62': 'Mexico',
#  'JPN32': 'Japan',
#  'USA73': 'United States',
#  'USA101': 'United States',
#  'USA83': 'United States',
#  'MEX39': 'Mexico',
#  'USA105': 'United States',
#  'USA75': 'United States',
#  'DE026': 'Germany',
#  'MEX16': 'Mexico',
#  'USA52': 'United States',
#  'UK003': 'United Kingdom',
#  'MEX55': 'Mexico',
#  'NL006': 'Netherlands',
#  'ES008': 'Spain',
#  'MEX59': 'Mexico',
#  'IE002': 'Ireland',
#  'JPN40': 'Japan',
#  'DE079': 'Germany',
#  'FR003': 'France',
#  'MEX56': 'Mexico',
#  'MEX10': 'Mexico',
#  'CAN04': 'Canada',
#  'UK539': 'United Kingdom',
#  'MEX54': 'Mexico',
#  'DE510': 'Germany',
#  'NL004': 'Netherlands',
#  'USA81': 'United States',
#  'DE507': 'Germany',
#  'USA165': 'United States',
#  'CL006': 'Chile',
#  'USA97': 'United States',
#  'PL008': 'Poland',
#  'USA29': 'United States',
#  'PL013': 'Poland',
#  'CL022': 'Chile',
#  'AT001': 'Austria',
#  'USA128': 'United States',
#  'USA30': 'United States',
#  'DK003': 'Denmark',
#  'PL002': 'Poland',
#  'USA26': 'United States',
#  'NL008': 'Netherlands',
#  'DE057': 'Germany',
#  'USA134': 'United States',
#  'USA115': 'United States',
#  'FR028': 'France',
#  'KOR07': 'South Korea',
#  'UK023': 'United Kingdom',
#  'DK001': 'Denmark',
#  'JPN22': 'Japan',
#  'UK018': 'United Kingdom',
#  'PL012': 'Poland',
#  'JPN28': 'Japan',
#  'MEX29': 'Mexico',
#  'COL08': 'Colombia',
#  'SE001': 'Senegal',
#  'MEX37': 'Mexico',
#  'COL10': 'Colombia',
#  'USA117': 'United States',
#  'UK528': 'United Kingdom',
#  'MEX04': 'Mexico',
#  'USA123': 'United States',
#  'USA37': 'United States',
#  'AUS05': 'Australia',
#  'USA148': 'United States',
#  'MEX07': 'Mexico',
#  'DK002': 'Denmark',
#  'CZ002': 'Czech Republic',
#  'DE533': 'Germany',
#  'DE007': 'Germany',
#  'KOR14': 'South Korea',
#  'ES026': 'Spain',
#  'IT027': 'Italy',
#  'USA42': 'United States',
#  'USA13': 'United States',
#  'MEX08': 'Mexico',
#  'NL003': 'Netherlands',
#  'IT503': 'Italy',
#  'FR048': 'France',
#  'MEX12': 'Mexico',
#  'ES532': 'Spain',
#  'PT002': 'Portugal',
#  'CH001': 'China',
#  'DE522': 'Germany',
#  'PL006': 'Poland',
#  'USA143': 'United States',
#  'DE002': 'Germany',
#  'MEX60': 'Mexico',
#  'JPN45': 'Japan',
#  'JPN43': 'Japan',
#  'KOR03': 'South Korea',
#  'FR010': 'France',
#  'ES005': 'Spain',
#  'USA164': 'United States',
#  'UK001': 'United Kingdom',
#  'DE549': 'Germany',
#  'CAN13': 'Canada',
#  'USA152': 'United States',
#  'PL024': 'Poland',
#  'IT006': 'Italy',
#  'USA65': 'United States',
#  'JPN48': 'Japan',
#  'FR044': 'France',
#  'USA136': 'United States',
#  'USA126': 'United States',
#  'USA03': 'United States',
#  'JPN31': 'Japan',
#  'ES023': 'Spain',
#  'UK027': 'United Kingdom',
#  'DE077': 'Germany',
#  'MEX03': 'Mexico',
#  'USA95': 'United States',
#  'KOR15': 'South Korea',
#  'DE546': 'Germany',
#  'UK516': 'United Kingdom',
#  'DE084': 'Germany',
#  'USA01': 'United States',
#  'MEX02': 'Mexico',
#  'FR006': 'France',
#  'USA55': 'United States',
#  'JPN47': 'Japan',
#  'IT022': 'Italy',
#  'JPN37': 'Japan',
#  'USA86': 'United States',
#  'ES007': 'Spain',
#  'DE548': 'Germany',
#  'USA05': 'United States',
#  'USA161': 'United States',
#  'USA59': 'United States',
#  'FR025': 'France',
#  'JPN50': 'Japan',
#  'FI002': 'Finland',
#  'USA32': 'United States',
#  'MEX49': 'Mexico',
#  'NL503': 'Netherlands',
#  'MEX42': 'Mexico',
#  'IE001': 'Ireland',
#  'USA41': 'United States',
#  'PL010': 'Poland',
#  'JPN35': 'Japan',
#  'IT010': 'Italy',
#  'CAN16': 'Canada',
#  'NL009': 'Netherlands',
#  'FR203': 'France',
#  'USA140': 'United States',
#  'DE035': 'Germany',
#  'FR207': 'France',
#  'CAN12': 'Canada',
#  'JPN05': 'Japan',
#  'USA09': 'United States',
#  'MEX31': 'Mexico',
#  'COL12': 'Colombia',
#  'DE038': 'Germany',
#  'MEX14': 'Mexico',
#  'NL507': 'Netherlands',
#  'IT005': 'Italy',
#  'USA145': 'United States',
#  'USA48': 'United States',
#  'USA158': 'United States',
#  'USA21': 'United States',
#  'AT003': 'Austria',
#  'USA80': 'United States',
#  'USA98': 'United States',
#  'UK033': 'United Kingdom',
#  'NL001': 'Netherlands',
#  'ES025': 'Spain',
#  'USA16': 'United States',
#  'FR045': 'France',
#  'JPN13': 'Japan',
#  'FR038': 'France',
#  'USA107': 'United States',
#  'USA79': 'United States',
#  'JPN34': 'Japan',
#  'MEX27': 'Mexico',
#  'DE064': 'Germany',
#  'JPN04': 'Japan',
#  'DE008': 'Germany',
#  'COL01': 'Colombia',
#  'FR018': 'France',
#  'MEX11': 'Mexico',
#  'USA28': 'United States',
#  'IT008': 'Italy',
#  'MEX28': 'Mexico',
#  'IT502': 'Italy',
#  'CAN07': 'Canada',
#  'JPN24': 'Japan',
#  'PL015': 'Poland',
#  'USA22': 'United States',
#  'USA87': 'United States',
#  'JPN46': 'Japan',
#  'UK004': 'United Kingdom',
#  'COL02': 'Colombia',
#  'USA23': 'United States',
#  'AUS11': 'Australia',
#  'USA58': 'United States',
#  'DE537': 'Germany',
#  'ES015': 'Spain',
#  'FR032': 'France',
#  'USA112': 'United States',
#  'CZ003': 'Czech Republic',
#  'IT028': 'Italy',
#  'USA10': 'United States',
#  'FR022': 'France',
#  'PL009': 'Poland',
#  'FR030': 'France',
#  'MEX01': 'Mexico',
#  'DE005': 'Germany',
#  'USA160': 'United States',
#  'SK001': 'Slovakia',
#  'USA111': 'United States',
#  'AUS08': 'Australia',
#  'IT007': 'Italy',
#  'MEX19': 'Mexico',
#  'CAN02': 'Canada',
#  'ES022': 'Spain',
#  'USA71': 'United States',
#  'FR026': 'France',
#  'USA43': 'United States',
#  'CAN06': 'Canada',
#  'USA74': 'United States',
#  'CL017': 'Chile',
#  'ES019': 'Spain',
#  'USA82': 'United States',
#  'PL003': 'Poland',
#  'COL09': 'Colombia',
#  'AT006': 'Austria',
#  'ES533': 'Spain',
#  'UK019': 'United Kingdom',
#  'COL17': 'Colombia',
#  'USA137': 'United States',
#  'COL25': 'Colombia',
#  'MEX45': 'Mexico',
#  'JPN30': 'Japan',
#  'BE001': 'Benin',
#  'COL07': 'Colombia',
#  'USA156': 'United States',
#  'NL002': 'Netherlands',
#  'USA125': 'United States',
#  'MEX22': 'Mexico',
#  'UK568': 'United Kingdom',
#  'UK520': 'United Kingdom',
#  'JPN38': 'Japan',
#  'USA84': 'United States',
#  'CH002': 'China',
#  'DE524': 'Germany',
#  'JPN39': 'Japan',
#  'DE020': 'Germany',
#  'MEX40': 'Mexico',
#  'AUS04': 'Australia',
#  'USA102': 'United States',
#  'KOR16': 'South Korea',
#  'HU001': 'Hungary',
#  'IT032': 'Italy',
#  'USA88': 'United States',
#  'ES006': 'Spain',
#  'KOR08': 'South Korea',
#  'PL007': 'Poland',
#  'USA167': 'United States',
#  'FR202': 'France',
#  'AUS02': 'Australia',
#  'FR036': 'France',
#  'UK557': 'United Kingdom',
#  'MEX52': 'Mexico',
#  'ES014': 'Spain',
#  'USA149': 'United States',
#  'SI001': 'Slovakia',
#  'USA67': 'United States',
#  'USA50': 'United States',
#  'FR042': 'France',
#  'BE002': 'Benin',
#  'COL11': 'Colombia',
#  'FR012': 'France',
#  'USA121': 'United States',
#  'AUS01': 'Australia',
#  'MEX18': 'Mexico',
#  'ES012': 'Spain',
#  'USA06': 'United States',
#  'MEX46': 'Mexico',
#  'USA162': 'United States',
#  'CL023': 'Chile',
#  'DE027': 'Germany',
#  'MEX21': 'Mexico',
#  'UK569': 'United Kingdom',
#  'UK515': 'United Kingdom',
#  'FR017': 'France',
#  'USA61': 'United States',
#  'USA33': 'United States',
#  'JPN23': 'Japan',
#  'AT005': 'Austria',
#  'USA99': 'United States',
#  'CZ001': 'Czech Republic',
#  'EL002': 'Greece',
#  'USA07': 'United States',
#  'UK011': 'United Kingdom',
#  'BE005': 'Benin',
#  'DE527': 'Germany',
#  'JPN33': 'Japan',
#  'USA142': 'United States',
#  'MEX33': 'Mexico',
#  'USA153': 'United States',
#  'DE032': 'Germany',
#  'FR035': 'France',
#  'USA139': 'United States',
#  'FR021': 'France',
#  'FR024': 'France',
#  'JPN17': 'Japan',
#  'CAN08': 'Canada',
#  'CL004': 'Chile',
#  'JPN16': 'Japan',
#  'USA56': 'United States',
#  'MEX26': 'Mexico',
#  'IT511': 'Italy',
#  'USA54': 'United States',
#  'MEX17': 'Mexico',
#  'IT505': 'Italy',
#  'DE534': 'Germany',
#  'DE011': 'Germany',
#  'UK029': 'United Kingdom',
#  'AUS14': 'Australia',
#  'FR019': 'France',
#  'USA141': 'United States',
#  'USA93': 'United States',
#  'USA46': 'United States',
#  'USA57': 'United States',
#  'UK518': 'United Kingdom',
#  'USA90': 'United States',
#  'CAN14': 'Canada',
#  'USA64': 'United States',
#  'DE009': 'Germany',
#  'USA92': 'United States',
#  'NO001': 'Norway',
#  'USA170': 'United States',
#  'FR011': 'France',
#  'USA24': 'United States',
#  'MEX32': 'Mexico',
#  'CAN05': 'Canada',
#  'JPN11': 'Japan',
#  'USA151': 'United States',
#  'DE523': 'Germany',
#  'USA36': 'United States',
#  'USA63': 'United States',
#  'COL13': 'Colombia',
#  'DE069': 'Germany',
#  'JPN54': 'Japan',
#  'JPN19': 'Japan',
#  'USA130': 'United States',
#  'PL506': 'Poland',
#  'USA154': 'United States',
#  'USA31': 'United States',
#  'UK552': 'United Kingdom',
#  'IT001': 'Italy',
#  'MEX47': 'Mexico',
#  'KOR01': 'South Korea',
#  'HU007': 'Hungary',
#  'UK007': 'United Kingdom',
#  'USA38': 'United States',
#  'USA53': 'United States',
#  'UK517': 'United Kingdom',
#  'AT002': 'Austria',
#  'USA109': 'United States',
#  'SI002': 'Slovakia',
#  'DE039': 'Germany',
#  'USA78': 'United States',
#  'DE003': 'Germany',
#  'ES010': 'Spain',
#  'UK506': 'United Kingdom',
#  'JPN53': 'Japan',
#  'UK008': 'United Kingdom',
#  'NL012': 'Netherlands',
#  'USA69': 'United States',
#  'COL14': 'Colombia',
#  'USA19': 'United States',
#  'MEX58': 'Mexico',
#  'UK559': 'United Kingdom',
#  'ES003': 'Spain',
#  'KOR02': 'South Korea',
#  'USA129': 'United States',
#  'UK010': 'United Kingdom',
#  'CL014': 'Chile',
#  'JPN36': 'Japan',
#  'MEX66': 'Mexico',
#  'UK030': 'United Kingdom',
#  'JPN02': 'Japan',
#  'USA127': 'United States',
#  'USA147': 'United States',
#  'JPN12': 'Japan',
#  'USA39': 'United States',
#  'USA169': 'United States',
#  'MEX64': 'Mexico',
#  'MEX34': 'Mexico',
#  'DK004': 'Denmark',
#  'HU009': 'Hungary',
#  'USA155': 'United States',
#  'DE019': 'Germany',
#  'FR023': 'France',
#  'USA11': 'United States',
#  'FR001': 'France',
#  'USA104': 'United States',
#  'CAN03': 'Canada',
#  'DE061': 'Germany',
#  'IT002': 'Italy',
#  'SE002': 'Senegal',
#  'NL013': 'Netherlands',
#  'USA47': 'United States',
#  'DE532': 'Germany',
#  'USA70': 'United States',
#  'MEX48': 'Mexico',
#  'ES001': 'Spain',
#  'FR520': 'France',
#  'ES013': 'Spain',
#  'COL16': 'Colombia',
#  'UK025': 'United Kingdom',
#  'DE001': 'Germany',
#  'UK017': 'United Kingdom',
#  'MEX38': 'Mexico',
#  'USA94': 'United States',
#  'UK016': 'United Kingdom',
#  'NL010': 'Netherlands',
#  'CAN09': 'Canada',
#  'NL005': 'Netherlands',
#  'AUS10': 'Australia',
#  'USA122': 'United States',
#  'FR004': 'France',
#  'FI004': 'Finland',
#  'NO003': 'Norway',
#  'COL03': 'Colombia',
#  'NO002': 'Norway',
#  'USA76': 'United States',
#  'ES510': 'Spain',
#  'MEX20': 'Mexico',
#  'MEX43': 'Mexico',
#  'MEX24': 'Mexico',
#  'USA157': 'United States',
#  'USA27': 'United States',
#  'MEX15': 'Mexico',
#  'USA150': 'United States',
#  'DE037': 'Germany',
#  'DE073': 'Germany',
#  'JPN06': 'Japan',
#  'USA62': 'United States',
#  'JPN15': 'Japan',
#  'USA120': 'United States',
#  'NO004': 'Norway',
#  'DE033': 'Germany',
#  'PL025': 'Poland',
#  'FR046': 'France',
#  'CL020': 'Chile',
#  'DE504': 'Germany',
#  'DE014': 'Germany',
#  'USA85': 'United States',
#  'USA77': 'United States',
#  'UK510': 'United Kingdom',
#  'COL20': 'Colombia',
#  'IT003': 'Italy',
#  'ES009': 'Spain',
#  'KOR09': 'South Korea',
#  'UK013': 'United Kingdom',
#  'KOR18': 'South Korea',
#  'JPN44': 'Japan',
#  'FR043': 'France',
#  'DE513': 'Germany',
#  'DE013': 'Germany',
#  'UK014': 'United Kingdom',
#  'COL06': 'Colombia',
#  'COL15': 'Colombia',
#  'MEX05': 'Mexico'}

# %%
#Create dataframe for country
df_country_city = pd.DataFrame.from_dict(dict_country_city, orient='index')
df_country_city.rename(columns = {0:'Country'}, inplace = True)

# %%
#Prepare extra variables for merging with data

#Inland water
inland_water_15 = country_inlandwater[country_inlandwater['Year']==2015]
inland_water_15 = inland_water_15[inland_water_15['MEAS']=='PCNT']
inland_water_15 = inland_water_15[['Country','Value']]
inland_water_15

#Road density
road_density = country_roaddensity[['Country','Amount']]
road_density

#merge first two
road_and_water = pd.merge(inland_water_15,road_density,how="inner",on='Country')
road_and_water

#merge with main dataframe
df_country_city_ext = df_country_city.reset_index().merge(road_and_water, how="left").set_index('index')
df_country_city_ext.rename(columns = {'Value':'CNTRY_INlAND_WATER','Amount':'CNTRY_ROAD_DENS'}, inplace = True)
df_country_city_ext
# Out:
#               Country  CNTRY_INlAND_WATER CNTRY_ROAD_DENS
# index
# USA08   United States            2.360209              68
# AT004         Austria            0.821240          127.82
# USA66   United States            2.360209              68
# JPN42           Japan            1.477841             316
# ES501           Spain            0.756209             132
# ...               ...                 ...             ...
# DE013         Germany            1.241050          180.51
# UK014  United Kingdom            1.421405          172.41
# COL06        Colombia            1.263969           14.81
# COL15        Colombia            1.263969           14.81
# MEX05          Mexico            1.405378           18.33
#
# [668 rows x 3 columns]

# %%
#Now we add relative territory of the city
